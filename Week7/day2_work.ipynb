# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv'
cars_df = pd.read_csv(url).dropna(subset=['Manufacturer', 'Price'])

# %%
cars_df.head()
pd.get_dummies(cars_df, columns=['Manufacturer'])
# Out:
#       Model     Type  Min.Price  Price  Max.Price  MPG.city  MPG.highway  \
# 0   Integra    Small       12.9   15.9       18.8      25.0         31.0
# 2        90  Compact       25.9   29.1       32.3      20.0         26.0
# 3       100  Midsize        NaN   37.7       44.6      19.0         26.0
# 4      535i  Midsize        NaN   30.0        NaN      22.0         30.0
# 5   Century  Midsize       14.2   15.7       17.3      22.0         31.0
# ..      ...      ...        ...    ...        ...       ...          ...
# 87      Fox    Small        8.7    9.1        9.5      25.0         33.0
# 88  Eurovan      Van       16.6   19.7       22.7      17.0         21.0
# 89   Passat  Compact       17.6   20.0       22.4      21.0         30.0
# 90  Corrado   Sporty       22.9   23.3       23.7      18.0         25.0
# 91      240  Compact       21.8   22.7       23.5      21.0         28.0
#
#                AirBags DriveTrain Cylinders  ...  Manufacturer_Nissan  \
# ...

# %%
cars_df['Model'].unique()
# Out:
# array(['Integra', '90', '100', '535i', 'Century', 'LeSabre', 'Roadmaster',
#        'Riviera', 'DeVille', 'Seville', 'Cavalier', 'Corsica', 'Camaro',
#        'Lumina', 'Lumina_APV', 'Astro', 'Caprice', 'Corvette', 'LeBaron',
#        'Imperial', 'Colt', 'Shadow', 'Spirit', 'Caravan', 'Dynasty',
#        'Stealth', 'Summit', 'Vision', 'Festiva', 'Escort', 'Tempo',
#        'Mustang', 'Probe', 'Aerostar', 'Taurus', 'Crown_Victoria',
#        'Metro', 'Storm', 'Prelude', 'Civic', 'Accord', 'Excel', 'Elantra',
#        'Scoupe', 'Sonata', 'Q45', 'ES300', 'Continental', 'Town_Car',
#        '323', 'Protege', '626', 'MPV', 'RX-7', '190E', '300E', nan,
#        'Cougar', 'Mirage', 'Diamante', 'Sentra', 'Altima', 'Quest',
#        'Maxima', 'Achieva', 'Cutlass_Ciera', 'Silhouette', 'Eighty-Eight',
#        'Laser', 'LeMans', 'Sunbird', 'Firebird', 'Grand_Prix',
#        'Bonneville', '900', 'Justy', 'Loyale', 'Legacy', 'Swift',
# ...

# %%
cars_df.Weight
# Out:
# 0     2705.0
# 2     3375.0
# 3     3405.0
# 4     3640.0
# 5        NaN
#        ...
# 87    2240.0
# 88    3960.0
# 89    2985.0
# 90    2810.0
# 91    2985.0
# Name: Weight, Length: 87, dtype: float64

# %%
cars_df['weightbinned'] = pd.cut(cars_df.Weight, bins=range(2000, 4001, 500), retbins=False,include_lowest=True)
cars_df
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# 5         Buick  Century  Midsize       14.2   15.7       17.3      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 87   Volkswagen      Fox    Small        8.7    9.1        9.5      25.0
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
#
#     MPG.highway             AirBags DriveTrain  ... Length  Wheelbase  Width  \
# ...

# %%
pd.get_dummies(cars_df, columns=['weightbinned'])
# Out:
#    Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9   15.9       18.8      25.0
# 2          Audi       90  Compact       25.9   29.1       32.3      20.0
# 3          Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4           BMW     535i  Midsize        NaN   30.0        NaN      22.0
# 5         Buick  Century  Midsize       14.2   15.7       17.3      22.0
# ..          ...      ...      ...        ...    ...        ...       ...
# 87   Volkswagen      Fox    Small        8.7    9.1        9.5      25.0
# 88   Volkswagen  Eurovan      Van       16.6   19.7       22.7      17.0
# 89   Volkswagen   Passat  Compact       17.6   20.0       22.4      21.0
# 90   Volkswagen  Corrado   Sporty       22.9   23.3       23.7      18.0
# 91        Volvo      240  Compact       21.8   22.7       23.5      21.0
#
#     MPG.highway             AirBags DriveTrain  ... Turn.circle  \
# ...
